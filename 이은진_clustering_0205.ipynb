# %%
import os

os.chdir('C:/Users/EunJin/Desktop/dacon/뱅크샐러드/train')
os.getcwd()
# Out:
# 'C:\\Users\\EunJin\\Desktop\\dacon\\뱅크샐러드\\train'

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

df = pd.read_csv('result.csv',index_col=0)
df.head(10)
# Out:
#    store_id  n_card  count  total_amount  count/n_card  total_amount/n_card  \
# 0         0   12727  68773       5234611      5.403709           411.299678
# 1         1       8     40        147950      5.000000         18493.750000
# 2         2    9053  16829       1615060      1.858942           178.400530
# 3         3     231    383         62781      1.658009           271.779221
# 4         4    1176   2082        270312      1.770408           229.857143
# 5         5     101    124        184437      1.227723          1826.108911
# 6         6    1899   2653       1389983      1.397051           731.955240
# 7         7      74    122        109510      1.648649          1479.864865
# 8         8     558   1153        515535      2.066308           923.897849
# 9         9       9     13         19760      1.444444          2195.555556
#
#    weekdays_count  weekend_count  weekdays_avg  weekend_avg  weekdays_sum  \
# 0         48232.0        20541.0        9646.4      10270.5     3595164.0
# 1            39.0            1.0           7.8          0.5      135950.0
# 2         13238.0         3591.0        2647.6       1795.5     1247258.0
# 3           377.0            6.0          75.4          3.0       61296.0
# 4          1336.0          746.0         267.2        373.0      173262.0
# 5            73.0           51.0          14.6         25.5      112237.0
# 6          1798.0          855.0         359.6        427.5      942937.0
# 7           113.0            9.0          22.6          4.5      101210.0
# 8           774.0          379.0         154.8        189.5      349615.0
# 9            13.0          375.0           2.6        187.5       19760.0
#
#    weekend_sum  weekdays_amount_avg  weekend_amount_avg  regular_percent  \
# 0    1639447.0             719032.8            819723.5        26.890745
# 1      12000.0              27190.0              6000.0         4.285714
# 2     367802.0             249451.6            183901.0         3.810448
# 3       1485.0              12259.2               742.5         5.339463
# 4      97050.0              34652.4             48525.0         7.916793
# 5      72200.0              22447.4             36100.0         1.620370
# 6     447046.0             188587.4            223523.0         5.624049
# 7       8300.0              20242.0              4150.0         2.238806
# 8     165920.0              69923.0             82960.0        10.869295
# 9     288753.0               3952.0            144376.5        11.111111
#
#    t01_05  t06_10  t11_14  t15_17  t18_20  t21_24     p01_05     p06_10  \
# 0    5989    7583    9400   11697   17568   16536   8.708359  11.026129
# 1       0       0       3      26      10       1   0.000000   0.000000
# 2     944    1779    8887    1240    2379    1600   5.609365  10.571038
# 3       0       2     180     170      31       0   0.000000   0.522193
# 4       0      19    1332     250     481       0   0.000000   0.912584
# 5       0      11      39      45      25       4   0.000000   8.870968
# 6       0      10    1146     258     970     269   0.000000   0.376932
# 7       0       1       9      22      65      25   0.000000   0.819672
# 8     453       0       0       2       5     693  39.288812   0.000000
# 9       0       0      11       1       0       1   0.000000   0.000000
#
#       p11_14     p15_17     p18_20     p21_24  holiday_total_amount  \
# 0  13.668155  17.008128  25.544909  24.044320              308833.0
# 1   7.500000  65.000000  25.000000   2.500000                   0.0
# 2  52.807653   7.368233  14.136312   9.507398               42772.0
# 3  46.997389  44.386423   8.093995   0.000000                 455.0
# 4  63.976945  12.007685  23.102786   0.000000                7085.0
# 5  31.451613  36.290323  20.161290   3.225806               14034.0
# 6  43.196381   9.724840  36.562382  10.139465               66520.0
# 7   7.377049  18.032787  53.278689  20.491803                6250.0
# 8   0.000000   0.173461   0.433651  60.104076               36835.0
# 9  84.615385   7.692308   0.000000   7.692308                   0.0
#
#    n_holiday  n_days  total_amount/n_days  holiday_amount/n_holiday
# 0       31.0     591          8857.209814               9962.354839
# 1        0.0      36          4109.722222                       NaN
# 2       30.0     722          2236.925208               1425.733333
# 3        3.0     251           250.123506                151.666667
# 4       12.0     367           736.544959                590.416667
# 5        3.0     107          1723.710280               4678.000000
# 6       33.0     704          1974.407670               2015.757576
# 7        4.0     105          1042.952381               1562.500000
# 8       31.0     562           917.322064               1188.225806
# 9        0.0      10          1976.000000                       NaN

# %%
df.fillna(0, inplace=True)

# %%
df.describe()
# Out:
#           store_id        n_card         count  total_amount  count/n_card  \
# count  1775.000000   1775.000000   1775.000000  1.775000e+03   1775.000000
# mean    897.965070   1012.883944   1894.532958  2.765304e+05      1.829936
# std     519.243611   1801.812073   4056.018623  5.318239e+05      1.236499
# min       0.000000      1.000000      1.000000  0.000000e+00      1.000000
# 25%     448.500000     58.000000    102.500000  3.738550e+04      1.263180
# 50%     896.000000    322.000000    492.000000  1.206910e+05      1.484734
# 75%    1346.500000   1156.000000   1940.000000  3.074290e+05      1.933476
# max    1799.000000  18456.000000  68773.000000  9.474601e+06     18.571429
#
#        total_amount/n_card  weekdays_count  weekend_count  weekdays_avg  \
# count          1775.000000     1775.000000    1775.000000   1775.000000
# mean           1425.708624     1333.829296     560.703662    266.765859
# std            5905.883932     2888.144220    1242.663617    577.628844
# min               0.000000        0.000000       0.000000      0.000000
# 25%             165.841221       73.000000      15.500000     14.600000
# 50%             298.633540      334.000000     124.000000     66.800000
# 75%             786.238217     1319.500000     525.000000    263.900000
# max          157343.750000    48232.000000   20541.000000   9646.400000
#
#         weekend_avg  weekdays_sum   weekend_sum  weekdays_amount_avg  \
# count   1775.000000  1.775000e+03  1.775000e+03         1.775000e+03
# mean     280.351831  1.981458e+05  7.838463e+04         3.962915e+04
# std      621.331808  3.880570e+05  1.605545e+05         7.761140e+04
# min        0.000000  0.000000e+00 -3.012410e+05         0.000000e+00
# 25%        7.750000  2.785350e+04  5.903000e+03         5.570700e+03
# 50%       62.000000  8.637500e+04  2.683000e+04         1.727500e+04
# 75%      262.500000  2.225075e+05  8.548550e+04         4.450150e+04
# max    10270.500000  7.074846e+06  2.399755e+06         1.414969e+06
#
#        weekend_amount_avg  regular_percent       t01_05        t06_10  \
# count        1.775000e+03      1775.000000  1775.000000   1775.000000
# mean         3.919231e+04         7.985436    67.971268    129.714930
# std          8.027724e+04         9.437633   288.857021    652.626452
# min         -1.506205e+05         0.000000     0.000000      0.000000
# 25%          2.951500e+03         2.583010     0.000000      0.000000
# 50%          1.341500e+04         5.238095     0.000000      2.000000
# 75%          4.274275e+04        10.152530     6.000000     15.000000
# max          1.199878e+06       100.000000  5989.000000  10384.000000
#
#              t11_14        t15_17       t18_20        t21_24       p01_05  \
# count   1775.000000   1775.000000   1775.00000   1775.000000  1775.000000
# mean     551.101972    319.896901    504.07493    321.772958     4.342572
# std     1310.342387    794.764670   1035.51530    829.720808    10.564669
# min        0.000000      0.000000      0.00000      0.000000     0.000000
# 25%        4.000000      9.000000     15.00000      1.000000     0.000000
# 50%       50.000000     52.000000    112.00000     33.000000     0.000000
# 75%      424.000000    255.000000    524.50000    274.500000     1.189581
# max    13442.000000  11697.000000  17568.00000  16536.000000    63.291139
#
#             p06_10       p11_14       p15_17       p18_20       p21_24  \
# count  1775.000000  1775.000000  1775.000000  1775.000000  1775.000000
# mean      4.482660    26.255385    20.395535    26.135953    18.387894
# std       9.262952    20.817000    16.689224    15.969872    22.049975
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     6.475373     6.676329    13.977551     0.348046
# 50%       0.364299    25.666884    17.772969    26.112186     7.692308
# 75%       4.795908    40.508027    32.247453    36.383767    31.836982
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#        holiday_total_amount    n_holiday       n_days  total_amount/n_days  \
# count           1775.000000  1775.000000  1775.000000          1775.000000
# mean           11323.585915    11.197183   270.512676          1259.376019
# std            23984.138108    10.984128   234.089832          2718.817133
# min            -3850.000000     0.000000     1.000000             0.000000
# 25%              550.000000     2.000000    62.500000           345.553747
# 50%             3540.000000     7.000000   195.000000           653.020633
# 75%            11979.500000    18.000000   461.000000          1298.064734
# max           342140.000000    37.000000   730.000000         57750.000000
#
#        holiday_amount/n_holiday
# count               1775.000000
# mean                 774.546243
# std                 1308.484931
# min                -1925.000000
# 25%                  157.928571
# 50%                  434.375000
# 75%                  898.567927
# max                19142.100000

# %%
df.columns
# Out:
# Index(['store_id', 'n_card', 'count', 'total_amount', 'count/n_card',
#        'total_amount/n_card', 'weekdays_count', 'weekend_count',
#        'weekdays_avg', 'weekend_avg', 'weekdays_sum', 'weekend_sum',
#        'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent',
#        't01_05', 't06_10', 't11_14', 't15_17', 't18_20', 't21_24', 'p01_05',
#        'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24',
#        'holiday_total_amount', 'n_holiday', 'n_days', 'total_amount/n_days',
#        'holiday_amount/n_holiday'],
#       dtype='object')

# %%
df1 = df.drop([ 't01_05', 't06_10', 't11_14', 't15_17', 't18_20',
       't21_24','holiday_total_amount','weekdays_count',
       'weekend_count','weekdays_sum',
       'weekend_sum','n_holiday', 'n_days'], axis=1)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings
warnings.filterwarnings('ignore')
from matplotlib import rc
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scale_df = df.drop(['store_id'],axis=1)
scaler.fit(scale_df)
scale_df = scaler.transform(scale_df)

# %%
scaler = StandardScaler()
scale_df1 = df1.drop(['store_id'],axis=1)
scaler.fit(scale_df1)
scale_df1 = scaler.transform(scale_df1)

# %% [markdown]
# # Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Dendograms")
dend = shc.dendrogram(shc.linkage(scale_df, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='ward')
cluster.fit_predict(scale_df)
# Out:
# array([8, 6, 0, ..., 9, 5, 9], dtype=int64)

# %%
df['cluster'] = cluster.fit_predict(scale_df)
print(df.cluster.value_counts())
# Out:
# 9    789
# 1    327
# 5    300
# 0    120
# 2     89
# 6     78
# 4     63
# 3      5
# 7      3
# 8      1
# Name: cluster, dtype: int64

# %% [markdown]
# # df1

# %%
df1.columns
# Out:
# Index(['store_id', 'n_card', 'count', 'total_amount', 'count/n_card',
#        'total_amount/n_card', 'weekdays_avg', 'weekend_avg',
#        'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent',
#        'p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24',
#        'total_amount/n_days', 'holiday_amount/n_holiday'],
#       dtype='object')

# %%
# scale_df1

plt.figure(figsize=(10, 7))
plt.title("Dendograms")
dend = shc.dendrogram(shc.linkage(scale_df1, method='ward'))

# %%
cluster1 = AgglomerativeClustering(n_clusters=9, affinity='euclidean', linkage='ward')
cluster1.fit_predict(scale_df1)
# Out:
# array([4, 2, 1, ..., 2, 2, 2], dtype=int64)

# %%
df1['cluster'] = cluster1.fit_predict(scale_df1)
print(df1.cluster.value_counts())
# Out:
# 2    844
# 5    271
# 8    234
# 1    165
# 0    138
# 6     99
# 7     17
# 4      4
# 3      3
# Name: cluster, dtype: int64

# %%
pd.DataFrame(df1.groupby(['cluster'])['p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24'].mean())
# Out:
#          p01_05  p06_10  p11_14  p15_17  p18_20  p21_24
# cluster
# 0        2.2655 22.9753 36.5959 22.0387 10.8008  5.3237
# 1        1.4217  7.3352 34.9567 20.2105 26.0919  9.9840
# 2        0.1547  3.2611 35.4667 29.5190 26.1251  5.4734
# 3        0.0000 29.6610 60.7345  9.0395  0.5650  0.0000
# 4        4.6595 24.7373 21.9992 19.0745 18.0832 11.4462
# 5       23.5660  0.8073  1.9292  2.7248 15.0000 55.9727
# 6        2.6438  2.7046 23.2094 17.0919 30.4921 23.8582
# 7        0.6617  4.7015 37.5064 18.9713 25.8786 12.2806
# 8        1.5054  0.2951  9.0724  8.7843 46.7880 33.5547

# %%
pd.DataFrame(df1.groupby(['cluster'])['n_card', 'total_amount','count', 'count/n_card',
       'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent','total_amount/n_days', 'holiday_amount/n_holiday'].mean())
# Out:
#             n_card  total_amount      count  count/n_card  \
# cluster
# 0         568.3768   158362.6812  1919.7754        3.2263
# 1        4698.7758  1031369.7152  9211.7758        1.9992
# 2         520.6730   147741.2488   864.2654        1.8071
# 3           3.6667   490750.0000    21.0000        3.4583
# 4       11675.0000  6811653.5000 42149.0000        3.6766
# 5         850.8450   290852.0959  1255.4133        1.5238
# 6         608.7778   183386.3535  1011.8990        1.5793
# 7         729.7059   215286.0000  1301.5294        1.4317
# 8         661.2094   191294.4145   928.6496        1.4067
#
#          weekdays_amount_avg  weekend_amount_avg  regular_percent  \
# cluster
# 0                 29408.7507          37272.8442          22.7013
# 1                 54025.0691          32734.3606           8.7868
# 2                 25616.2137          31648.5142           6.9792
# 3                 50649.6667           1417.0000           1.4815
# 4                397984.4500         252383.3750          18.1392
# 5                 29254.8900          44570.3063           7.4632
# 6                200865.8343          23092.3081           5.9588
# 7                 42153.3647         548832.6765           7.8336
# 8                 23396.7171          32485.2970           3.7542
#
#          total_amount/n_days  holiday_amount/n_holiday
# cluster
# 0                  2619.5240                  288.5789
# 1                  2249.3934                 2441.3525
# 2                   904.0494                  506.5613
# 3                 43652.2436                    0.0000
# 4                 16613.4262                13977.8920
# 5                   974.6480                  876.1571
# 6                   894.9167                  565.7791
# 7                   992.5192                  590.9426
# 8                   738.1236                  620.6259

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df1.drop(['store_id','count','total_amount','total_amount/n_card','weekdays_avg','weekend_avg','cluster'],axis=1).corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
len(df1.drop(['store_id'],axis=1).columns)
# Out:
# 19

# %% [markdown]
# # df2

# %%
df2  = df1.drop(['count','total_amount','total_amount/n_card','weekdays_avg','weekend_avg'],axis=1)

# %%
df2.columns
# Out:
# Index(['store_id', 'n_card', 'count/n_card', 'weekdays_amount_avg',
#        'weekend_amount_avg', 'regular_percent', 'p01_05', 'p06_10', 'p11_14',
#        'p15_17', 'p18_20', 'p21_24', 'total_amount/n_days',
#        'holiday_amount/n_holiday', 'cluster'],
#       dtype='object')

# %%
scaler = StandardScaler()
scale_df2 = df2.drop(['store_id'],axis=1)
scaler.fit(scale_df2)
scale_df2 = scaler.transform(scale_df2)

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))
plt.title("Dendograms df2")
dend = shc.dendrogram(shc.linkage(scale_df2, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster2 = AgglomerativeClustering(n_clusters=8, affinity='euclidean', linkage='ward')
cluster2.fit_predict(scale_df2)
# Out:
# array([0, 4, 6, ..., 4, 4, 4], dtype=int64)

# %%
df2['cluster'] = cluster2.fit_predict(scale_df2)
print(df2.cluster.value_counts())
# Out:
# 4    881
# 1    319
# 2    264
# 6    123
# 5     91
# 7     42
# 3     28
# 0     27
# Name: cluster, dtype: int64

# %%
pd.DataFrame(df2.cluster.value_counts())
# Out:
#    cluster
# 4      881
# 1      319
# 2      264
# 6      123
# 5       91
# 7       42
# 3       28
# 0       27

# %%
pd.set_option('display.float_format', lambda x: '%.4f' % x)
pd.DataFrame(df2.groupby(['cluster'])['p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24'].mean())
# Out:
#          p01_05  p06_10  p11_14  p15_17  p18_20  p21_24
# cluster
# 0        0.9929 15.0856 42.3076 28.0632 10.0499  3.5008
# 1        1.4353  1.1138 12.1463 11.3971 43.5723 30.3352
# 2       24.1221  0.8799  3.1406  3.0469 12.9509 55.8596
# 3       10.3501 11.8677 18.5292 22.4576 17.6730 19.1224
# 4        0.1732  3.3873 35.8164 29.0306 26.0586  5.5338
# 5        0.3242 28.4696 40.9115 20.8549  8.0812  1.3586
# 6        1.7809  7.2782 33.6701 19.0923 27.2133 10.9652
# 7        3.9096  3.7937 19.5180 13.1766 30.1488 29.4532

# %%
pd.DataFrame(df2.groupby(['cluster'])['n_card',  'count/n_card',
       'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent','total_amount/n_days', 'holiday_amount/n_holiday'].mean())
# Out:
#            n_card  count/n_card  weekdays_amount_avg  weekend_amount_avg  \
# cluster
# 0       2010.4815        2.8236           82196.1778          50485.3889
# 1        815.7116        1.4264           75328.8006          25578.4671
# 2        650.2689        1.5129           31100.3379          30292.0549
# 3        701.6429        7.4945           35759.3929          50516.3750
# 4        621.6561        1.8228           26228.4711          31433.8428
# 5        635.8132        2.0794           28790.0066          31297.1923
# 6       5311.8211        2.0497           61362.4667          27076.5407
# 7        789.6429        1.4373           38239.3714         399059.2143
#
#          regular_percent  total_amount/n_days  holiday_amount/n_holiday
# cluster
# 0                14.6409           16991.0086                 4852.5889
# 1                 3.7420             823.5990                  668.1355
# 2                 7.9243             942.5042                  805.2641
# 3                49.1228             769.2332                  289.0317
# 4                 7.2972             928.8301                  520.8196
# 5                14.9006            1187.7386                  255.9856
# 6                 8.5158            2261.6971                 2422.2410
# 7                 6.7980             927.9801                  712.1310

# %% [markdown]
# # df1으로 결정

# %% [markdown]
# ## 레이터 차트

# %%
pd.DataFrame(df1.groupby(['cluster'])['p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24'].mean()).reset_index()
# Out:
#    cluster  p01_05  p06_10  p11_14  p15_17  p18_20  p21_24
# 0        0  2.2655 22.9753 36.5959 22.0387 10.8008  5.3237
# 1        1  1.4217  7.3352 34.9567 20.2105 26.0919  9.9840
# 2        2  0.1547  3.2611 35.4667 29.5190 26.1251  5.4734
# 3        3  0.0000 29.6610 60.7345  9.0395  0.5650  0.0000
# 4        4  4.6595 24.7373 21.9992 19.0745 18.0832 11.4462
# 5        5 23.5660  0.8073  1.9292  2.7248 15.0000 55.9727
# 6        6  2.6438  2.7046 23.2094 17.0919 30.4921 23.8582
# 7        7  0.6617  4.7015 37.5064 18.9713 25.8786 12.2806
# 8        8  1.5054  0.2951  9.0724  8.7843 46.7880 33.5547

# %%
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

df = pd.DataFrame(df1.groupby(['cluster'])['p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24'].mean()).reset_index()
labels = df.columns[1:]
num_labels = len(labels)
    
angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)] ## 각 등분점
angles += angles[:1] ## 시작점으로 다시 돌아와야하므로 시작점 추가
    
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
fig = plt.figure(figsize=(15,15))
fig.set_facecolor('white')
 
for i, row in df.iterrows():
    color = my_palette(i)
    data = df.iloc[i].drop('cluster').tolist()
    data += data[:1]
    
    ax = plt.subplot(3,3, i+1, polar=True)
    ax.set_theta_offset(pi / 2) ## 시작점
    ax.set_theta_direction(-1) ## 그려지는 방향 시계방향
    
    #ax.set_xticklabels(angles[:-1], labels, fontsize=13)
    plt.xticks(angles[:-1], labels, fontsize=13) ## x축 눈금 라벨
    ax.tick_params(axis='x', which='major', pad=15) ## x축과 눈금 사이에 여백을 준다.
 
    ax.set_rlabel_position(0) ## y축 각도 설정(degree 단위)
    plt.yticks([0,10,20,30,40,50],['0','10','20','30','40','50'], fontsize=10) ## y축 눈금 설정
    plt.ylim(0,55)
    
    ax.plot(angles, data, color=color, linewidth=2, linestyle='solid') ## 레이더 차트 출력
    ax.fill(angles, data, color=color, alpha=0.4) ## 도형 안쪽에 색을 채워준다.
    
    plt.title(row.cluster, size=20, color=color,x=-0.2, y=1.2, ha='left') ## 타이틀은 캐릭터 클래스로 한다.
 

plt.tight_layout(pad=5) ## subplot간 패딩 조절
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

df = pd.DataFrame(df1.groupby(['cluster'])['n_card','total_amount/n_card', 'count/n_card','regular_percent',
       'weekdays_amount_avg', 'weekend_amount_avg'].mean()).reset_index()
labels = df.columns[1:]
num_labels = len(labels)


scaler = MinMaxScaler()
output = df.drop(['cluster'],axis=1)
scaler.fit(output)
output = scaler.transform(output)

output = pd.DataFrame(output, columns=labels, index=list(df.index.values))
output['cluster'] = df['cluster']
    
angles = [x/float(num_labels)*(2*pi) for x in range(num_labels)] ## 각 등분점
angles += angles[:1] ## 시작점으로 다시 돌아와야하므로 시작점 추가
    
my_palette = plt.cm.get_cmap("Set2", len(output.index))
 
fig = plt.figure(figsize=(20,20))
fig.set_facecolor('white')
 
for i, row in output.iterrows():
    color = my_palette(i)
    data = output.iloc[i].drop('cluster').tolist()
    data += data[:1]
    
    ax = plt.subplot(3,3, i+1, polar=True)
    ax.set_theta_offset(pi / 2) ## 시작점
    ax.set_theta_direction(-1) ## 그려지는 방향 시계방향
    
    #ax.set_xticklabels(angles[:-1], labels, fontsize=13)
    plt.xticks(angles[:-1], labels, fontsize=13) ## x축 눈금 라벨
    ax.tick_params(axis='x', which='major', pad=15) ## x축과 눈금 사이에 여백을 준다.
 
    ax.set_rlabel_position(0) ## y축 각도 설정(degree 단위)
    plt.yticks([0,0.2,0.4,0.6,0.8],['0','1','2','3','4'], fontsize=10) ## y축 눈금 설정
    plt.ylim(0,1)
    
    ax.plot(angles, data, color=color, linewidth=2, linestyle='solid') ## 레이더 차트 출력
    ax.fill(angles, data, color=color, alpha=0.4) ## 도형 안쪽에 색을 채워준다.
    
    plt.title(row.cluster, size=20, color=color,x=-0.2, y=1.2, ha='left') ## 타이틀은 캐릭터 클래스로 한다.
 

plt.tight_layout(pad=5) ## subplot간 패딩 조절
plt.show()

# %%
df1.head()
# Out:
#    store_id  n_card  count  total_amount  count/n_card  total_amount/n_card  \
# 0         0   12727  68773       5234611        5.4037             411.2997
# 1         1       8     40        147950        5.0000           18493.7500
# 2         2    9053  16829       1615060        1.8589             178.4005
# 3         3     231    383         62781        1.6580             271.7792
# 4         4    1176   2082        270312        1.7704             229.8571
#
#    weekdays_avg  weekend_avg  weekdays_amount_avg  weekend_amount_avg  \
# 0     9646.4000   10270.5000          719032.8000         819723.5000
# 1        7.8000       0.5000           27190.0000           6000.0000
# 2     2647.6000    1795.5000          249451.6000         183901.0000
# 3       75.4000       3.0000           12259.2000            742.5000
# 4      267.2000     373.0000           34652.4000          48525.0000
#
#    regular_percent  p01_05  p06_10  p11_14  p15_17  p18_20  p21_24  \
# 0          26.8907  8.7084 11.0261 13.6682 17.0081 25.5449 24.0443
# 1           4.2857  0.0000  0.0000  7.5000 65.0000 25.0000  2.5000
# 2           3.8104  5.6094 10.5710 52.8077  7.3682 14.1363  9.5074
# 3           5.3395  0.0000  0.5222 46.9974 44.3864  8.0940  0.0000
# 4           7.9168  0.0000  0.9126 63.9769 12.0077 23.1028  0.0000
#
#    total_amount/n_days  holiday_amount/n_holiday  cluster
# 0            8857.2098                 9962.3548        4
# 1            4109.7222                    0.0000        2
# 2            2236.9252                 1425.7333        1
# 3             250.1235                  151.6667        2
# 4             736.5450                  590.4167        2

# %%
pd.DataFrame(df1.groupby(['cluster'])['n_card', 'total_amount','count', 'total_amount/n_card','count/n_card',
       'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent','total_amount/n_days', 'holiday_amount/n_holiday'].mean())
# Out:
#             n_card  total_amount      count  total_amount/n_card  \
# cluster
# 0         568.3768   158362.6812  1919.7754            4752.3866
# 1        4698.7758  1031369.7152  9211.7758             858.6891
# 2         520.6730   147741.2488   864.2654            1229.7640
# 3           3.6667   490750.0000    21.0000          104364.5833
# 4       11675.0000  6811653.5000 42149.0000             605.5017
# 5         850.8450   290852.0959  1255.4133             677.5129
# 6         608.7778   183386.3535  1011.8990             706.9820
# 7         729.7059   215286.0000  1301.5294             600.8296
# 8         661.2094   191294.4145   928.6496             495.1788
#
#          count/n_card  weekdays_amount_avg  weekend_amount_avg  \
# cluster
# 0              3.2263           29408.7507          37272.8442
# 1              1.9992           54025.0691          32734.3606
# 2              1.8071           25616.2137          31648.5142
# 3              3.4583           50649.6667           1417.0000
# 4              3.6766          397984.4500         252383.3750
# 5              1.5238           29254.8900          44570.3063
# 6              1.5793          200865.8343          23092.3081
# 7              1.4317           42153.3647         548832.6765
# 8              1.4067           23396.7171          32485.2970
#
#          regular_percent  total_amount/n_days  holiday_amount/n_holiday
# cluster
# 0                22.7013            2619.5240                  288.5789
# 1                 8.7868            2249.3934                 2441.3525
# 2                 6.9792             904.0494                  506.5613
# 3                 1.4815           43652.2436                    0.0000
# 4                18.1392           16613.4262                13977.8920
# 5                 7.4632             974.6480                  876.1571
# 6                 5.9588             894.9167                  565.7791
# 7                 7.8336             992.5192                  590.9426
# 8                 3.7542             738.1236                  620.6259

# %%
df1.columns
# Out:
# Index(['store_id', 'n_card', 'count', 'total_amount', 'count/n_card',
#        'total_amount/n_card', 'weekdays_avg', 'weekend_avg',
#        'weekdays_amount_avg', 'weekend_amount_avg', 'regular_percent',
#        'p01_05', 'p06_10', 'p11_14', 'p15_17', 'p18_20', 'p21_24',
#        'total_amount/n_days', 'holiday_amount/n_holiday', 'cluster'],
#       dtype='object')

# %%
df1.to_csv('cluster.csv')

# %%
df1.head()
# Out:
#    store_id  n_card  count  total_amount  count/n_card  total_amount/n_card  \
# 0         0   12727  68773       5234611        5.4037             411.2997
# 1         1       8     40        147950        5.0000           18493.7500
# 2         2    9053  16829       1615060        1.8589             178.4005
# 3         3     231    383         62781        1.6580             271.7792
# 4         4    1176   2082        270312        1.7704             229.8571
#
#    weekdays_avg  weekend_avg  weekdays_amount_avg  weekend_amount_avg  \
# 0     9646.4000   10270.5000          719032.8000         819723.5000
# 1        7.8000       0.5000           27190.0000           6000.0000
# 2     2647.6000    1795.5000          249451.6000         183901.0000
# 3       75.4000       3.0000           12259.2000            742.5000
# 4      267.2000     373.0000           34652.4000          48525.0000
#
#    regular_percent  p01_05  p06_10  p11_14  p15_17  p18_20  p21_24  \
# 0          26.8907  8.7084 11.0261 13.6682 17.0081 25.5449 24.0443
# 1           4.2857  0.0000  0.0000  7.5000 65.0000 25.0000  2.5000
# 2           3.8104  5.6094 10.5710 52.8077  7.3682 14.1363  9.5074
# 3           5.3395  0.0000  0.5222 46.9974 44.3864  8.0940  0.0000
# 4           7.9168  0.0000  0.9126 63.9769 12.0077 23.1028  0.0000
#
#    total_amount/n_days  holiday_amount/n_holiday  cluster
# 0            8857.2098                 9962.3548        4
# 1            4109.7222                    0.0000        2
# 2            2236.9252                 1425.7333        1
# 3             250.1235                  151.6667        2
# 4             736.5450                  590.4167        2
